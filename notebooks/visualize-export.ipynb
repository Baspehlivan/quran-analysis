# %% [markdown]
# # Optional local visualization and CSV export; no corpus or results are embedded.

# %%
import csv
from pathlib import Path
rows = list(csv.DictReader(Path("result.csv").open(encoding="utf-8")))
len(rows)
