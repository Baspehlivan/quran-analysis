# %% [markdown]
# # Compare canonical query payloads through the public API (CLI parity).

# %%
from pathlib import Path
from quran_analysis import ResearchQuery
a = ResearchQuery.loads(Path("examples/research/exact-token.json").read_text())
a.to_dict()
